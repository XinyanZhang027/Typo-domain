# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
# @Time    : 2019/10/21 3:46 PM
# @Author  : w8ay
# @File    : domain.py.py

import requests
from bs4 import BeautifulSoup
import time
from itertools import combinations, permutations


# 查询是否注册
def check(domain):
    url = "http://panda.www.net.cn/cgi-bin/check.cgi?area_domain="+domain
    html = requests.get(url)
    bsj = BeautifulSoup(html.text, "lxml")
    onum = bsj.find("original")
    if onum != None:
        num = onum.get_text()[:3]
        if num == '210':
            print("%s可以注册" % domain)
        elif num == "213":
            print("查询超时，请重新查询")
        elif num == "211":
            print("[x] %s" % domain)
        elif num == "212":
            print(f"{domain} 无效域名")
        else:
            print(html.text)
            print("出现未知问题")
        return num
    else:
        print("让我哭一会，ip可能被封了")
        return None


def search(name, suffix):
    domain = name + '.' + suffix
    num = check(domain)
    if num != None:
        if num == '210':
            return domain
    return False
# Out:
# y.a 无效域名
# y.a 无效域名
# y.a 无效域名
# y.a 无效域名
# y.a 无效域名
# a.h 无效域名
# y.h 无效域名
# y.a 无效域名
# a.y 无效域名
# y.a 无效域名
# b.y 无效域名
# y.b 无效域名
# c.y 无效域名
# y.c 无效域名
# d.y 无效域名
# y.d 无效域名
# e.y 无效域名
# y.e 无效域名
# f.y 无效域名
# y.f 无效域名
# g.y 无效域名
# y.g 无效域名
# h.y 无效域名
# y.h 无效域名
# i.y 无效域名
# y.i 无效域名
# j.y 无效域名
# y.j 无效域名
# k.y 无效域名
# y.k 无效域名
# l.y 无效域名
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# C:\Anaconda\Anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# C:\Anaconda\Anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# C:\Anaconda\Anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\Anaconda\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# C:\Anaconda\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     391         else:
# --> 392             conn.request(method, url, **httplib_request_kw)
#     393
#
# C:\Anaconda\Anaconda\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# C:\Anaconda\Anaconda\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# C:\Anaconda\Anaconda\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1249             raise CannotSendHeader()
# -> 1250         self._send_output(message_body, encode_chunked=encode_chunked)
#    1251
#
# C:\Anaconda\Anaconda\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1009         del self._buffer[:]
# -> 1010         self.send(msg)
#    1011
#
# C:\Anaconda\Anaconda\lib\http\client.py in send(self, data)
#     949             if self.auto_open:
# --> 950                 self.connect()
#     951             else:
#
# C:\Anaconda\Anaconda\lib\site-packages\urllib3\connection.py in connect(self)
#     186     def connect(self):
# --> 187         conn = self._new_conn()
#     188         self._prepare_conn(conn)
#
# C:\Anaconda\Anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170         except SocketError as e:
# --> 171             raise NewConnectionError(
#     172                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x00D7C6B8>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\Anaconda\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# C:\Anaconda\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# C:\Anaconda\Anaconda\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     445         if new_retry.is_exhausted():
# --> 446             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     447
#
# MaxRetryError: HTTPConnectionPool(host='panda.www.net.cn', port=80): Max retries exceeded with url: /cgi-bin/check.cgi?area_domain=y.l (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00D7C6B8>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-9-a188ed493c89> in <module>
#      49     domains = ['yaho.com', 'yahoo.co', 'yahoo.om', 'yaoo.com', 'yahoo.cm', 'ahoo.com', 'yhoo.com', 'yahooo.com', 'ayahoo.com', 'yaahoo.com', 'byahoo.com', 'ybahoo.com', 'cyahoo.com', 'ycahoo.com', 'dyahoo.com', 'ydahoo.com', 'eyahoo.com', 'yeahoo.com', 'fyahoo.com', 'yfahoo.com', 'gyahoo.com', 'ygahoo.com', 'hyahoo.com', 'yhahoo.com', 'iyahoo.com', 'yiahoo.com', 'jyahoo.com', 'yjahoo.com', 'kyahoo.com', 'ykahoo.com', 'lyahoo.com', 'ylahoo.com', 'myahoo.com', 'ymahoo.com', 'nyahoo.com', 'ynahoo.com', 'oyahoo.com', 'yoahoo.com', 'pyahoo.com', 'ypahoo.com', 'qyahoo.com', 'yqahoo.com', 'ryahoo.com', 'yrahoo.com', 'syahoo.com', 'ysahoo.com', 'tyahoo.com', 'ytahoo.com', 'uyahoo.com', 'yuahoo.com', 'vyahoo.com', 'yvahoo.com', 'wyahoo.com', 'ywahoo.com', 'xyahoo.com', 'yxahoo.com', '
oo.com', 'yahoto.com', 'yahuoo.com', 'yahouo.com', 'yahvoo.com', 'yahovo.com', 'yahwoo.com', 'yahowo.com', 'yahxoo.com', 'yahoxo.com', 'yahyoo.com', 'yahoyo.com', 'yahzoo.com', 'yahozo.com', 'yahoao.com', 'yahooa.com', 'yahobo.com', 'yahoob.com', 'yahoco.com', 'yahooc.com', 'yahodo.com', 'yahood.com', 'yahoeo.com', 'yahooe.com', 'yahofo.com', 'yahoof.com', 'yahogo.com', 'yahoog.com', 'yahoho.com', 'yahooh.com', 'yahoio.com', 'yahooi.com', 'yahojo.com', 'yahooj.com', 'yahoko.com', 'yahook.com', 'yaholo.com', 'yahool.com', 'yahomo.com', 'yahoom.com', 'yahono.com', 'yahoon.com', 'yahooo.com', 'yahooo.com', 'yahopo.com', 'yahoop.com', 'yahoqo.com', 'yahooq.com', 'yahoro.com', 'yahoor.com', 'yahoso.com', 'yahoos.com', 'yahoto.com', 'yahoot.com', 'yahouo.com', 'yahoou.com', 'yahovo.com', 'yahoov.com', 'yahowo.com', 'yahoow.com', 'yahoxo.com', 'yahoox.com', 'yahoyo.com', 'yahooy.com', 'yahozo.com', 'yahooz.com', 'yhaoo.com', 'ayhoo.com', 'yaoho.com', 'yahoo.cmo', 'yahoo.ocm', 'yahoo.com', 'tahoo.com', 'uahoo.com', 'hahoo.com', 'yqhoo.com', 'ywhoo.com', 'yshoo.com', 'yzhoo.com', 'yayoo.com', 'yauoo.com', 'yagoo.com', 'yajoo.com', 'yaboo.com', 'yano ...
#      50     for domain in domains:
# ---> 51         oklist = search(domain[0], domain[1])
#      52         time.sleep(0.1)
#
# <ipython-input-9-a188ed493c89> in search(name, suffix)
#      38 def search(name, suffix):
#      39     domain = name + '.' + suffix
# ---> 40     num = check(domain)
#      41     if num != None:
#      42         if num == '210':
#
# <ipython-input-9-a188ed493c89> in check(domain)
#      14 def check(domain):
#      15     url = "http://panda.www.net.cn/cgi-bin/check.cgi?area_domain="+domain
# ---> 16     html = requests.get(url)
#      17     bsj = BeautifulSoup(html.text, "lxml")
#      18     onum = bsj.find("original")
#
# C:\Anaconda\Anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# C:\Anaconda\Anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# C:\Anaconda\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# C:\Anaconda\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# C:\Anaconda\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='panda.www.net.cn', port=80): Max retries exceeded with url: /cgi-bin/check.cgi?area_domain=y.l (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00D7C6B8>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。'))

# %%
if __name__ == '__main__':

    domains = ['sina.co', 'sia.com', 'ina.com', 'sna.com', 'sin.com', 'sina.cm', 'sina.om', 'asina.com', 'saina.com', 'bsina.com', 'sbina.com', 'csina.com', 'scina.com', 'dsina.com', 'sdina.com', 'esina.com', 'seina.com', 'fsina.com', 'sfina.com', 'gsina.com', 'sgina.com', 'hsina.com', 'shina.com', 'isina.com', 'siina.com', 'jsina.com', 'sjina.com', 'ksina.com', 'skina.com', 'lsina.com', 'slina.com', 'msina.com', 'smina.com', 'nsina.com', 'snina.com', 'osina.com', 'soina.com', 'psina.com', 'spina.com', 'qsina.com', 'sqina.com', 'rsina.com', 'srina.com', 'ssina.com', 'ssina.com', 'tsina.com', 'stina.com', 'usina.com', 'suina.com', 'vsina.com', 'svina.com', 'wsina.com', 'swina.com', 'xsina.com', 'sxina.com', 'ysina.com', 'syina.com', 'zsina.com', 'szina.com', 'saina.com', 'siana.com', 'sbina.com', 'sibna.com', 'scina.com', 'sicna.com', 'sdina.com', 'sidna.com', 'seina.com', 'siena.com', 'sfina.com', 'sifna.com', 'sgina.com', 'signa.com', 'shina.com', 'sihna.com', 'siina.com', 'siina.com', 'sjina.com', 'sijna.com', 'skina.com', 'sikna.com', 'slina.com', 'silna.com', 'smina.com', 'simna.com', 'snina.com', 'sinna.com', 'soina.com', 'siona.com', 'spina.com', 'sipna.com', 'sqina.com', 'siqna.com', 'srina.com', 'sirna.com', 'ssina.com', 'sisna.com', 'stina.com', 'sitna.com', 'suina.com', 'siuna.com', 'svina.com', 'sivna.com', 'swina.com', 'siwna.com', 'sxina.com', 'sixna.com', 'syina.com', 'siyna.com', 'szina.com', 'sizna.com', 'siana.com', 'sinaa.com', 'sibna.com', 'sinba.com', 'sicna.com', 'sinca.com', 'sidna.com', 'sinda.com', 'siena.com', 'sinea.com', 'sifna.com', 'sinfa.com', 'signa.com', 'singa.com', 'sihna.com', 'sinha.com', 'siina.com', 'sinia.com', 'sijna.com', 'sinja.com', 'sikna.com', 'sinka.com', 'silna.com', 'sinla.com', 'simna.com', 'sinma.com', 'sinna.com', 'sinna.com', 'siona.com', 'sinoa.com', 'sipna.com', 'sinpa.com', 'siqna.com', 'sinqa.com', 'sirna.com', 'sinra.com', 'sisna.com', 'sinsa.com', 'sitna.com', 'sinta.com', 'siuna.com', 'sinua.com', 'sivna.com', 'sinva.com', 'siwna.com', 'sinwa.com', 'sixna.com', 'sinxa.com', 'siyna.com', 'sinya.com', 'sizna.com', 'sinza.com', 'sinaa.com', 'sinaa.com', 'sinba.com', 'sinab.com', 'sinca.com', 'sinac.com', 'sinda.com', 'sinad.com', 'sinea.com', 'sinae.com', 'sinfa.com', 'sinaf.com', 'singa.com', 'sinag.com', 'sinha.com', 'sinah.com', 'sinia.com', 'sinai.com', 'sinja.com', 'sinaj.com', 'sinka.com', 'sinak.com', 'sinla.com', 'sinal.com', 'sinma.com', 'sinam.com', 'sinna.com', 'sinan.com', 'sinoa.com', 'sinao.com', 'sinpa.com', 'sinap.com', 'sinqa.com', 'sinaq.com', 'sinra.com', 'sinar.com', 'sinsa.com', 'sinas.com', 'sinta.com', 'sinat.com', 'sinua.com', 'sinau.com', 'sinva.com', 'sinav.com', 'sinwa.com', 'sinaw.com', 'sinxa.com', 'sinax.com', 'sinya.com', 'sinay.com', 'sinza.com', 'sinaz.com', 'sina.cmo', 'snia.com', 'sian.com', 'isna.com', 'sina.ocm', 'wina.com', 'eina.com', 'aina.com', 'dina.com', 'zina.com', 'xina.com', 'suna.com', 'sona.com', 'skna.com', 'siha.com', 'sija.com', 'siba.com', 'sima.com', 'sinq.com', 'sinw.com', 'sins.com', 'sinz.com', 'wwwsina.com', 'singa.com']
    for domain in domains:
        oklist = search(domain[0], domain[1])
        time.sleep(0.1)
# Out:
# s.i 无效域名
# s.i 无效域名
# i.n 无效域名
# s.n 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# a.s 无效域名
# s.a 无效域名
# b.s 无效域名
# s.b 无效域名
# c.s 无效域名
# 让我哭一会，ip可能被封了
# d.s 无效域名
# s.d 无效域名
# e.s 无效域名
# s.e 无效域名
# f.s 无效域名
# s.f 无效域名
# g.s 无效域名
# s.g 无效域名
# h.s 无效域名
# s.h 无效域名
# i.s 无效域名
# s.i 无效域名
# j.s 无效域名
# s.j 无效域名
# k.s 无效域名
# s.k 无效域名
# l.s 无效域名
# s.l 无效域名
# m.s 无效域名
# s.m 无效域名
# n.s 无效域名
# s.n 无效域名
# o.s 无效域名
# s.o 无效域名
# p.s 无效域名
# s.p 无效域名
# q.s 无效域名
# s.q 无效域名
# r.s 无效域名
# s.r 无效域名
# s.s 无效域名
# s.s 无效域名
# t.s 无效域名
# s.t 无效域名
# u.s 无效域名
# s.u 无效域名
# v.s 无效域名
# s.v 无效域名
# w.s 无效域名
# s.w 无效域名
# x.s 无效域名
# s.x 无效域名
# y.s 无效域名
# 让我哭一会，ip可能被封了
# z.s 无效域名
# s.z 无效域名
# s.a 无效域名
# s.i 无效域名
# s.b 无效域名
# s.i 无效域名
# s.c 无效域名
# s.i 无效域名
# s.d 无效域名
# s.i 无效域名
# s.e 无效域名
# s.i 无效域名
# s.f 无效域名
# s.i 无效域名
# s.g 无效域名
# s.i 无效域名
# s.h 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.j 无效域名
# s.i 无效域名
# s.k 无效域名
# s.i 无效域名
# s.l 无效域名
# s.i 无效域名
# s.m 无效域名
# s.i 无效域名
# s.n 无效域名
# s.i 无效域名
# s.o 无效域名
# s.i 无效域名
# s.p 无效域名
# s.i 无效域名
# s.q 无效域名
# s.i 无效域名
# s.r 无效域名
# s.i 无效域名
# s.s 无效域名
# s.i 无效域名
# s.t 无效域名
# s.i 无效域名
# s.u 无效域名
# s.i 无效域名
# s.v 无效域名
# s.i 无效域名
# s.w 无效域名
# s.i 无效域名
# s.x 无效域名
# s.i 无效域名
# s.y 无效域名
# s.i 无效域名
# s.z 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# 让我哭一会，ip可能被封了
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.n 无效域名
# s.i 无效域名
# i.s 无效域名
# s.i 无效域名
# w.i 无效域名
# e.i 无效域名
# a.i 无效域名
# d.i 无效域名
# z.i 无效域名
# x.i 无效域名
# s.u 无效域名
# s.o 无效域名
# s.k 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# s.i 无效域名
# w.w 无效域名
# s.i 无效域名
